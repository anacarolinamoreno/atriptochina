# %% [markdown]
# # Data cleaning
# We have our raw dataset, now we need to make it ready for analysis

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import json
import warnings

# %% [markdown]
# ### Load raw dataset

# %%
raw = pd.read_csv("../00_raw/china_raw.csv", dtype={"cidade": str})
raw
# Out:
#         day    city                                          expense   price  \
# 0    12-May  Pequim            Didi pro templo do céu (tava fechado)   38.42
# 1    12-May  Pequim  Didi pro shopping das Pérolas (Hungqiao Market)   13.30
# 2    12-May  Pequim  Colar e brincos Carol + brinco presente da Lara  170.00
# 3    12-May  Pequim                                 Didi pra Qianmen   14.80
# 4    12-May  Pequim                                   Almoço Qianmen   64.00
# ..      ...     ...                                              ...     ...
# 124  29-May   Lhasa                                  Didi para Bokar     NaN
# 125  29-May   Lhasa                                           Almoço   33.00
# 126  29-May   Lhasa                        Compras Bokar Supermarket  105.00
# 127  29-May   Lhasa                            Massagem no aeroporto   30.00
# 128  29-May  Pequim                                Taxi do aeroporto  102.00
#
#     payment_source           category
# 0            Carol         Transporte
# 1            Carol         Transporte
# 2            Carol  Compras/Presentes
# 3            Carol         Transporte
# 4            Carol        Alimentação
# ..             ...                ...
# 124           Diva         Transporte
# 125           Diva        Alimentação
# 126          Carol  Compras/Presentes
# 127           Diva  Compras/Presentes
# 128          Paula         Transporte
#
# [129 rows x 6 columns]

# %% [markdown]
# ### Add missing rows
# When checking the AI generated dataset we noticed two issues:
# <br>
# 1- Some values are null
# <br>
# 2- Others are simply absent (from the dataset and the original source)
# <br>
# There's also a third issue:
# <br>
# 3- The price is sometimes for two people (Carol and Diva) and sometimes for three people (Carol, Diva and Renata). It's reasonable to say we want to find how much more one spends travelling to and in China.
# <br><br>
# The first issue was solved with **.apply()**:

# %%
# Issue 1: some expenses have an NA on the "price" column
no_price = raw.loc[pd.isna(raw["price"])]
no_price
# Out:
#         day      city               expense  price payment_source  \
# 51   17-May    Pequim                 Metrô    NaN           Diva
# 96   22-May    Pequim  Didi para Tiannanmen    NaN           Diva
# 97   22-May    Pequim       Almoço no museu    NaN           Diva
# 98   22-May    Pequim      Comprinhas museu    NaN           Diva
# 102  24-May     Lhasa    Didi pro aeroporto    NaN          Carol
# 111  27-May  Shigatse                Jantar    NaN          Carol
# 124  29-May     Lhasa       Didi para Bokar    NaN           Diva
#
#               category
# 51          Transporte
# 96          Transporte
# 97         Alimentação
# 98   Compras/Presentes
# 102         Transporte
# 111        Alimentação
# 124         Transporte

# %%
# Solution: apply and lambda
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 42 if "Didi para Tiannanmen" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 8 if "Metrô" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 165 if "Comprinhas museu" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 26 if "Almoço no museu" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 107 if "Didi pro aeroporto" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 52 if "Jantar" in row["expense"] else pd.NA, axis=1)
raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
    lambda row: 14 if "Didi para Bokar" in row["expense"] else pd.NA, axis=1)
raw
# Out:
# /var/folders/mp/9bbmxhdd5ms420hm5z9_6f000000gn/T/ipykernel_2457/3125365558.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[<NA> 42 <NA> <NA> <NA> <NA> <NA>]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   raw.loc[raw["price"].isna(), "price"] = raw.loc[raw["price"].isna()].apply(
#         day    city                                          expense  price  \
# 0    12-May  Pequim            Didi pro templo do céu (tava fechado)  38.42
# 1    12-May  Pequim  Didi pro shopping das Pérolas (Hungqiao Market)   13.3
# 2    12-May  Pequim  Colar e brincos Carol + brinco presente da Lara  170.0
# 3    12-May  Pequim                                 Didi pra Qianmen   14.8
# 4    12-May  Pequim                                   Almoço Qianmen   64.0
# ..      ...     ...                                              ...    ...
# 124  29-May   Lhasa                                  Didi para Bokar     14
# 125  29-May   Lhasa                                           Almoço   33.0
# 126  29-May   Lhasa                        Compras Bokar Supermarket  105.0
# 127  29-May   Lhasa                            Massagem no aeroporto   30.0
# 128  29-May  Pequim                                Taxi do aeroporto  102.0
#
#     payment_source           category
# 0            Carol         Transporte
# 1            Carol         Transporte
# 2            Carol  Compras/Presentes
# 3            Carol         Transporte
# 4            Carol        Alimentação
# ..             ...                ...
# 124           Diva         Transporte
# 125           Diva        Alimentação
# 126          Carol  Compras/Presentes
# 127           Diva  Compras/Presentes
# 128          Paula         Transporte
#
# [129 rows x 6 columns]

# %% [markdown]
# I solved the second issue (values that are relevant expenses but weren't on the original notes) by creating those rows myself and including other major expenses that weren't kept on the original file, such as airfares, train tickets, hotels and tour agency packages. These were paid for in advance, but I kept the day they were used to make the timeline better.
# <br><br>
# I saved that file as a json called **missing_data.json**, so now i can add the rows to the raw dataset, and get a more completed dataframe:

# %%
# Open the json with the data that was still missing:
missing_data = pd.read_json("../00_raw/missing_data.json", dtype={"cidade": str})
missing_data.head()
# Out:
#       day       city                              expense   price  \
# 0  13-May     Datong    Da Tong Weidu International Hotel   292.0
# 1  17-May     Suzhou                 HanTin Premium Hotel   656.0
# 2  18-May     Xangai                        Homeinn Hotel   970.0
# 3  31-May  Guangzhou  SunYat Sen University Kaifeng Hotel  1382.0
# 4  13-May     Datong           trem de Pequim para Datong   378.0
#
#   payment_source    category
# 0           Diva       Hotel
# 1         Renata       Hotel
# 2         Renata       Hotel
# 3         Renata       Hotel
# 4         Renata  Transporte

# %%
# Now let's concatenate both datasets
df_concat = pd.concat([raw, missing_data])
df_concat
# Out:
#        day       city                                          expense  \
# 0   12-May     Pequim            Didi pro templo do céu (tava fechado)
# 1   12-May     Pequim  Didi pro shopping das Pérolas (Hungqiao Market)
# 2   12-May     Pequim  Colar e brincos Carol + brinco presente da Lara
# 3   12-May     Pequim                                 Didi pra Qianmen
# 4   12-May     Pequim                                   Almoço Qianmen
# ..     ...        ...                                              ...
# 31  02-Jun  Guangzhou                                             Didi
# 32  02-Jun     Pequim                                Didi do aeroporto
# 33  03-Jun     Pequim                                 Massagem nos pés
# 34  03-Jun     Pequim                            Didi para o aeroporto
# 35  03-Jun     Pequim                                 Taobao e Meituan
#
#      price payment_source           category
# 0    38.42          Carol         Transporte
# 1     13.3          Carol         Transporte
# 2    170.0          Carol  Compras/Presentes
# 3     14.8          Carol         Transporte
# 4     64.0          Carol        Alimentação
# ..     ...            ...                ...
# 31   18.79          Carol         Transporte
# 32   110.0         Renata         Transporte
# 33   156.0          Carol  Compras/presentes
# 34    90.0         Renata         Transporte
# 35  840.47         Renata  Compras/presentes
#
# [165 rows x 6 columns]

# %%
# And reorder the rows by day
df = df_concat.sort_values("day")
df
# Out:
#        day       city                                     expense   price  \
# 27  01-Jun  Guangzhou                                      Jantar   120.0
# 26  01-Jun  Guangzhou                    Cruzeiro Rio das Pérolas   369.0
# 23  01-Jun  Guangzhou                                      Almoço    90.0
# 22  01-Jun  Guangzhou             Carro do aeroporto para o hotel   130.0
# 32  02-Jun     Pequim                           Didi do aeroporto   110.0
# ..     ...        ...                                         ...     ...
# 17  30-May     Pequim                  Almoço no bairro da Renata    66.0
# 20  30-May     Pequim                                Supermercado   19.39
# 16  30-May     Pequim                                Supermercado    21.3
# 10  31-May  Guangzhou  Avião ida e volta de Pequim para Guangzhou  6150.0
# 3   31-May  Guangzhou         SunYat Sen University Kaifeng Hotel  1382.0
#
#    payment_source           category
# 27           Diva        Alimentação
# 26         Renata          Ingressos
# 23           Diva        Alimentação
# 22         Renata         Transporte
# 32         Renata         Transporte
# ..            ...                ...
# 17           Diva        Alimentação
# 20          Carol        Alimentação
# 16          Carol  Compras/presentes
# 10         Renata         Transporte
# 3          Renata              Hotel
#
# [165 rows x 6 columns]

# %% [markdown]
# As for the third issue, I'm going to solve it using this logic:
# - On the cities only my mother and I visited (Beijing, Datong, Shanghai and Shigatse), I'll divide the price of expenses by 2.
# - On the other places (Suzhou, Lhasa and Guangzhou), I'll divide it by 3.
# <br>
# But first, let's convert the values to USD for a broader sense of the costs.

# %%
# Create a column converting the prices from yuan (or RMB, rembibi) to USD.
# We'll consider the currency conversion as 7.20 RMB for each dollar, more or less the value during May 2025.
df["price_usd"] = df["price"]/7.20
df
# Out:
#        day       city                                     expense   price  \
# 27  01-Jun  Guangzhou                                      Jantar   120.0
# 26  01-Jun  Guangzhou                    Cruzeiro Rio das Pérolas   369.0
# 23  01-Jun  Guangzhou                                      Almoço    90.0
# 22  01-Jun  Guangzhou             Carro do aeroporto para o hotel   130.0
# 32  02-Jun     Pequim                           Didi do aeroporto   110.0
# ..     ...        ...                                         ...     ...
# 17  30-May     Pequim                  Almoço no bairro da Renata    66.0
# 20  30-May     Pequim                                Supermercado   19.39
# 16  30-May     Pequim                                Supermercado    21.3
# 10  31-May  Guangzhou  Avião ida e volta de Pequim para Guangzhou  6150.0
# 3   31-May  Guangzhou         SunYat Sen University Kaifeng Hotel  1382.0
#
#    payment_source           category   price_usd
# 27           Diva        Alimentação   16.666667
# 26         Renata          Ingressos       51.25
# 23           Diva        Alimentação        12.5
# 22         Renata         Transporte   18.055556
# 32         Renata         Transporte   15.277778
# ..            ...                ...         ...
# 17           Diva        Alimentação    9.166667
# 20          Carol        Alimentação    2.693056
# 16          Carol  Compras/presentes    2.958333
# 10         Renata         Transporte  854.166667
# 3          Renata              Hotel  191.944444
#
# [165 rows x 7 columns]

# %%
# Create a dataset only with the expenses in Beijing, Datong, Shanghai and Shigatse and divide the price by TWO:
trip_for_two = df[df["city"].isin(["Pequim", "Datong", "Xangai", "Shigatse"])]
trip_for_two["price_usd"].astype(float)
trip_for_two["price_usd_per_capita"] = trip_for_two["price_usd"]/2
trip_for_two
# Out:
# /var/folders/mp/9bbmxhdd5ms420hm5z9_6f000000gn/T/ipykernel_2457/2805188022.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_for_two["price_usd_per_capita"] = trip_for_two["price_usd"]/2
#        day    city                                  expense   price  \
# 32  02-Jun  Pequim                        Didi do aeroporto   110.0
# 35  03-Jun  Pequim                         Taobao e Meituan  840.47
# 33  03-Jun  Pequim                         Massagem nos pés   156.0
# 34  03-Jun  Pequim                    Didi para o aeroporto    90.0
# 14  11-May  Pequim  Táxi do aeroporto para a casa da Renata    87.0
# ..     ...     ...                                      ...     ...
# 19  30-May  Pequim                Brincos e colar de pérola    70.0
# 18  30-May  Pequim                           Lenços de seda  1145.0
# 17  30-May  Pequim               Almoço no bairro da Renata    66.0
# 20  30-May  Pequim                             Supermercado   19.39
# 16  30-May  Pequim                             Supermercado    21.3
#
#    payment_source           category   price_usd price_usd_per_capita
# 32         Renata         Transporte   15.277778             7.638889
# 35         Renata  Compras/presentes  116.731944            58.365972
# 33          Carol  Compras/presentes   21.666667            10.833333
# 34         Renata         Transporte        12.5                 6.25
# 14          Carol         Transporte   12.083333             6.041667
# ..            ...                ...         ...                  ...
# 19           Diva  Compras/presentes    9.722222             4.861111
# 18          Paula  Compras/presentes  159.027778            79.513889
# 17           Diva        Alimentação    9.166667             4.583333
# 20          Carol        Alimentação    2.693056             1.346528
# 16          Carol  Compras/presentes    2.958333             1.479167
#
# [128 rows x 8 columns]

# %%
# Create a dataset only with the expenses in Suzhou, Lhasa and Guangzhou and divide the price by THREE:
trip_for_three = df[df["city"].isin(["Suzhou", "Lhasa", "Guangzhou"])]
trip_for_three["price_usd"].astype(float)
trip_for_three["price_usd_per_capita"] = trip_for_three["price_usd"]/3
trip_for_three
# Out:
# /var/folders/mp/9bbmxhdd5ms420hm5z9_6f000000gn/T/ipykernel_2457/4157605495.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_for_three["price_usd_per_capita"] = trip_for_three["price_usd"]/3
#         day       city                                     expense    price  \
# 27   01-Jun  Guangzhou                                      Jantar    120.0
# 26   01-Jun  Guangzhou                    Cruzeiro Rio das Pérolas    369.0
# 23   01-Jun  Guangzhou                                      Almoço     90.0
# 22   01-Jun  Guangzhou             Carro do aeroporto para o hotel    130.0
# 31   02-Jun  Guangzhou                                        Didi    18.79
# 30   02-Jun  Guangzhou                           Comprinhas Miniso     15.0
# 29   02-Jun  Guangzhou                                        Didi     17.1
# 28   02-Jun  Guangzhou                                       Museu     10.0
# 25   02-Jun  Guangzhou                       Café latte no M Stand     45.0
# 24   02-Jun  Guangzhou                                    Livraria     11.5
# 1    17-May     Suzhou                        HanTin Premium Hotel    656.0
# 6    17-May     Suzhou                  trem de Pequim para Suzhou   1224.0
# 7    18-May     Suzhou                  trem de Suzhou para Xangai    168.0
# 55   18-May     Suzhou                                       Metro      4.0
# 56   18-May     Suzhou     Entrada Jardim do Administrador Humilde    200.0
# 57   18-May     Suzhou                               Cartão-postal     10.0
# 58   18-May     Suzhou                       Café espresso + leite     20.0
# 105  24-May      Lhasa                                     Comidas     30.0
# 103  24-May      Lhasa                     Almoço hot pot surpresa    438.0
# 102  24-May      Lhasa                          Didi pro aeroporto      107
# 104  24-May      Lhasa                      Show Princesa Wejcheng    840.0
# 13   24-May      Lhasa                     Pacote de turismo Tibet  15183.0
# 9    24-May      Lhasa      Avião ida e volta de Pequim para Lhasa  9169.11
# 106  25-May      Lhasa                     Proteção (Jokar Temple)     50.0
# 107  25-May      Lhasa                         Porta-incenso e ímã     76.0
# 108  25-May      Lhasa                                      Bolsas    120.0
# 109  26-May      Lhasa                          Comprinhas mirante    150.0
# 126  29-May      Lhasa                   Compras Bokar Supermarket    105.0
# 125  29-May      Lhasa                                      Almoço     33.0
# 121  29-May      Lhasa                       Didi para Norbulingka     15.0
# 122  29-May      Lhasa                         Entrada Norbulingka    120.0
# 123  29-May      Lhasa                         Compras Norbulingka    308.0
# 124  29-May      Lhasa                             Didi para Bokar       14
# 127  29-May      Lhasa                       Massagem no aeroporto     30.0
# 10   31-May  Guangzhou  Avião ida e volta de Pequim para Guangzhou   6150.0
# 3    31-May  Guangzhou         SunYat Sen University Kaifeng Hotel   1382.0
#
#     payment_source           category   price_usd price_usd_per_capita
# 27            Diva        Alimentação   16.666667             5.555556
# 26          Renata          Ingressos       51.25            17.083333
# 23            Diva        Alimentação        12.5             4.166667
# 22          Renata         Transporte   18.055556             6.018519
# 31           Carol         Transporte    2.609722             0.869907
# 30           Carol  Compras/presentes    2.083333             0.694444
# 29           Carol         Transporte       2.375             0.791667
# 28           Carol          Ingressos    1.388889             0.462963
# 25            Diva        Alimentação        6.25             2.083333
# 24           Carol  Compras/presentes    1.597222             0.532407
# 1           Renata              Hotel   91.111111             30.37037
# 6           Renata         Transporte       170.0            56.666667
# 7           Renata         Transporte   23.333333             7.777778
# 55            Diva         Transporte    0.555556             0.185185
# 56           Carol          Ingressos   27.777778             9.259259
# 57           Carol  Compras/Presentes    1.388889             0.462963
# 58            Diva        Alimentação    2.777778             0.925926
# 105   Carol/Renata        Alimentação    4.166667             1.388889
# 103           Tica        Alimentação   60.833333            20.277778
# 102          Carol         Transporte   14.861111             4.953704
# 104           Tica          Ingressos  116.666667            38.888889
# 13           Paula            Agência     2108.75           702.916667
# 9            Paula         Transporte   1273.4875           424.495833
# 106         Renata  Compras/Presentes    6.944444             2.314815
# 107           Diva  Compras/Presentes   10.555556             3.518519
# 108           Tica  Compras/Presentes   16.666667             5.555556
# 109           Diva  Compras/Presentes   20.833333             6.944444
# 126          Carol  Compras/Presentes   14.583333             4.861111
# 125           Diva        Alimentação    4.583333             1.527778
# 121           Diva         Transporte    2.083333             0.694444
# 122           Diva          Ingressos   16.666667             5.555556
# 123           Diva  Compras/Presentes   42.777778            14.259259
# 124           Diva         Transporte    1.944444             0.648148
# 127           Diva  Compras/Presentes    4.166667             1.388889
# 10          Renata         Transporte  854.166667           284.722222
# 3           Renata              Hotel  191.944444            63.981481

# %%
# Concatenate the rows from the two datasets
df = pd.concat([trip_for_two, trip_for_three]).sort_values("day")
df
# Out:
#        day       city                                     expense   price  \
# 27  01-Jun  Guangzhou                                      Jantar   120.0
# 23  01-Jun  Guangzhou                                      Almoço    90.0
# 22  01-Jun  Guangzhou             Carro do aeroporto para o hotel   130.0
# 26  01-Jun  Guangzhou                    Cruzeiro Rio das Pérolas   369.0
# 31  02-Jun  Guangzhou                                        Didi   18.79
# ..     ...        ...                                         ...     ...
# 18  30-May     Pequim                              Lenços de seda  1145.0
# 19  30-May     Pequim                   Brincos e colar de pérola    70.0
# 21  30-May     Pequim                                       Metrô    14.0
# 10  31-May  Guangzhou  Avião ida e volta de Pequim para Guangzhou  6150.0
# 3   31-May  Guangzhou         SunYat Sen University Kaifeng Hotel  1382.0
#
#    payment_source           category   price_usd price_usd_per_capita
# 27           Diva        Alimentação   16.666667             5.555556
# 23           Diva        Alimentação        12.5             4.166667
# 22         Renata         Transporte   18.055556             6.018519
# 26         Renata          Ingressos       51.25            17.083333
# 31          Carol         Transporte    2.609722             0.869907
# ..            ...                ...         ...                  ...
# 18          Paula  Compras/presentes  159.027778            79.513889
# 19           Diva  Compras/presentes    9.722222             4.861111
# 21          Paula         Transporte    1.944444             0.972222
# 10         Renata         Transporte  854.166667           284.722222
# 3          Renata              Hotel  191.944444            63.981481
#
# [164 rows x 8 columns]

# %% [markdown]
# Now, for the final part in getting the data tidy, I'm going to specified the payment type.
# <br><br>
# This is important because China, unlike the US and Brazil, has the so-called superapps, such as Alipay, used to call a Didi, take the metro, order at restaurants and pay for things in stores, or WeChat, more common in more remote locations when a business or vendor wouldn't accept Alipay.
# <br><br>
# I can do this because I know that all expenses that have "Paula" as payment_source were paid for using our credit cards connected to Paula's bank account in the US.
# <br><br>
# And all the other names mean that the payment was made using Alipay, WeChat or other app purchases, like Taobao and Meituan. The money comes from Renata's bank account in China and stays in a digital wallet inside the apps.
# <br><br>
# I want to see **how much we've spent in total from each payment type**, and the *average spent in each purchase* from these two groups.

# %%
# Create new column "payment_type" and filling it according to the values in column "payment_source"
df["payment_type"] = df["payment_source"].apply(lambda x: "credit card" if x == "Paula" else "apps")
df
# Out:
#        day       city                                     expense   price  \
# 27  01-Jun  Guangzhou                                      Jantar   120.0
# 23  01-Jun  Guangzhou                                      Almoço    90.0
# 22  01-Jun  Guangzhou             Carro do aeroporto para o hotel   130.0
# 26  01-Jun  Guangzhou                    Cruzeiro Rio das Pérolas   369.0
# 31  02-Jun  Guangzhou                                        Didi   18.79
# ..     ...        ...                                         ...     ...
# 18  30-May     Pequim                              Lenços de seda  1145.0
# 19  30-May     Pequim                   Brincos e colar de pérola    70.0
# 21  30-May     Pequim                                       Metrô    14.0
# 10  31-May  Guangzhou  Avião ida e volta de Pequim para Guangzhou  6150.0
# 3   31-May  Guangzhou         SunYat Sen University Kaifeng Hotel  1382.0
#
#    payment_source           category   price_usd price_usd_per_capita  \
# 27           Diva        Alimentação   16.666667             5.555556
# 23           Diva        Alimentação        12.5             4.166667
# 22         Renata         Transporte   18.055556             6.018519
# 26         Renata          Ingressos       51.25            17.083333
# 31          Carol         Transporte    2.609722             0.869907
# ..            ...                ...         ...                  ...
# 18          Paula  Compras/presentes  159.027778            79.513889
# 19           Diva  Compras/presentes    9.722222             4.861111
# 21          Paula         Transporte    1.944444             0.972222
# 10         Renata         Transporte  854.166667           284.722222
# 3          Renata              Hotel  191.944444            63.981481
#
#    payment_type
# 27         apps
# 23         apps
# 22         apps
# 26         apps
# 31         apps
# ..          ...
# 18  credit card
# 19         apps
# 21  credit card
# 10         apps
# 3          apps
#
# [164 rows x 9 columns]

# %% [markdown]
# Just some final steps to get the dataframe as tidy as possible:

# %%
# Looks like our date format isn't helpful once there are two months involved.
# Let's fix it:
df["date"] = pd.Series(df["day"])
df["date"] = pd.to_datetime(df["date"], format='%d-%b')
df = df.sort_values("date", ascending=True)
df["date"] = df["date"].dt.strftime('%b-%d')
df.drop("day", axis=1, inplace=True)

# %%
# Turn the "price" and "price_per_capita" columns into float
df["price"] = df["price"].astype(float).round(2)
df["price_usd"] = df["price_usd"].astype(float).round(2)
df["price_usd_per_capita"] = df["price_usd_per_capita"].astype(float).round(2)

# Checking if it worked
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164 entries, 14 to 34
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   city                  164 non-null    object
#  1   expense               164 non-null    object
#  2   price                 164 non-null    float64
#  3   payment_source        164 non-null    object
#  4   category              164 non-null    object
#  5   price_usd             164 non-null    float64
#  6   price_usd_per_capita  164 non-null    float64
#  7   payment_type          164 non-null    object
#  8   date                  164 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 12.8+ KB

# %%
df.head()
# Out:
#       city                                          expense   price  \
# 14  Pequim          Táxi do aeroporto para a casa da Renata   87.00
# 10  Pequim          Didi pro restaurante de dumpling fritos   49.93
# 2   Pequim  Colar e brincos Carol + brinco presente da Lara  170.00
# 8   Pequim                                       3 Baralhos   90.00
# 6   Pequim                                            Metrô    6.00
#
#    payment_source           category  price_usd  price_usd_per_capita  \
# 14          Carol         Transporte      12.08                  6.04
# 10          Carol         Transporte       6.93                  3.47
# 2           Carol  Compras/Presentes      23.61                 11.81
# 8           Carol  Compras/Presentes      12.50                  6.25
# 6           Carol         Transporte       0.83                  0.42
#
#    payment_type    date
# 14         apps  May-11
# 10         apps  May-12
# 2          apps  May-12
# 8          apps  May-12
# 6          apps  May-12

# %% [markdown]
# Okay, now my dataframe is almost ready for the analyses I wanna do.
# <br>
# But it seems clear that it will be much better 100% in English.
# <br>
# So I'm going to save it as a json, to see if DeepSeek would translate it for me.

# %%
df.to_json("../04_tidy_data/china_df.json", orient="records", force_ascii=False, indent=4)

# %% [markdown]
# Should I have translated everything from the get go? **Maybe**.
# <br>
# Can we go back in time? **No**.
# <br>
# Am I learning something new everyday and becoming a Markdown genius? **Abso-*freaking*-lutely**!
# <br>
# Now let's get the translated json and check if the transation worked.

# %%
# Opening the new json into a dataframe
translated = pd.read_json("../04_tidy_data/china_df_t.json", dtype={"cidade": str})
translated
# Out:
#        date       city                                            expense  \
# 0    May-11    Beijing            Taxi from the airport to Renata's house
# 1    May-12    Beijing              Didi to the fried dumpling restaurant
# 2    May-12    Beijing  Necklace and earrings Carol + gift earring fro...
# 3    May-12    Beijing                                   3 Decks of cards
# 4    May-12    Beijing                                             Subway
# ..      ...        ...                                                ...
# 159  Jun-02  Guangzhou                                 Shopping at Miniso
# 160  Jun-02  Guangzhou                                               Didi
# 161  Jun-03    Beijing                                 Taobao and Meituan
# 162  Jun-03    Beijing                                       Foot massage
# 163  Jun-03    Beijing                                Didi to the airport
#
#     payment_source payment_type        category   price  price_usd  \
# 0            Carol         apps       Transport   87.00      12.08
# 1            Carol         apps       Transport   49.93       6.93
# 2            Carol         apps  Shopping/Gifts  170.00      23.61
# 3            Carol         apps  Shopping/Gifts   90.00      12.50
# 4            Carol         apps       Transport    6.00       0.83
# ..             ...          ...             ...     ...        ...
# 159          Carol         apps  Shopping/Gifts   15.00       2.08
# 160          Carol         apps       Transport   18.79       2.61
# 161         Renata         apps  Shopping/Gifts  840.47     116.73
# 162          Carol         apps  Shopping/Gifts  156.00      21.67
# 163         Renata         apps       Transport   90.00      12.50
#
#      price_usd_per_capita
# 0                    6.04
# 1                    3.47
# 2                   11.81
# 3                    6.25
# 4                    0.42
# ..                    ...
# 159                  0.69
# 160                  0.87
# 161                 58.37
# 162                 10.83
# 163                  6.25
#
# [164 rows x 9 columns]

# %%
# Comparing the shape of both dataframes
df.shape
# Out:
# (164, 9)

# %%
translated.shape
# Out:
# (164, 9)

# %% [markdown]
# We have the same number of rows and columns, great.
# <br>
# Now let's see if the content has been translated by looking at columns with few possible values:

# %%
# Cities 
translated.city.unique()
# Out:
# array(['Beijing', 'Datong', 'Suzhou', 'Shanghai', 'Mutianyu', 'Lhasa',
#        'China', 'Shigatse', 'Guangzhou'], dtype=object)

# %%
# Payment type
translated.payment_type.unique()
# Out:
# array(['apps', 'credit card'], dtype=object)

# %%
# Categories 
translated.category.unique()
# Out:
# array(['Transport', 'Shopping/Gifts', 'Food', 'Agency', 'Hotel',
#        'Tickets'], dtype=object)

# %%
# I didn't like how it translated some category names, so I'll replace them
translated["category"] = translated["category"].str.replace("Transport", "Transportation")
translated["category"] = translated["category"].str.replace("Shopping/Gifts", "Shopping")
translated["category"] = translated["category"].str.replace("Agency", "Tour Agency")
translated.rename(columns={ "date" : "month_day"}, inplace=True)
translated
# Out:
#     month_day       city                                            expense  \
# 0      May-11    Beijing            Taxi from the airport to Renata's house
# 1      May-12    Beijing              Didi to the fried dumpling restaurant
# 2      May-12    Beijing  Necklace and earrings Carol + gift earring fro...
# 3      May-12    Beijing                                   3 Decks of cards
# 4      May-12    Beijing                                             Subway
# ..        ...        ...                                                ...
# 159    Jun-02  Guangzhou                                 Shopping at Miniso
# 160    Jun-02  Guangzhou                                               Didi
# 161    Jun-03    Beijing                                 Taobao and Meituan
# 162    Jun-03    Beijing                                       Foot massage
# 163    Jun-03    Beijing                                Didi to the airport
#
#     payment_source payment_type        category   price  price_usd  \
# 0            Carol         apps  Transportation   87.00      12.08
# 1            Carol         apps  Transportation   49.93       6.93
# 2            Carol         apps        Shopping  170.00      23.61
# 3            Carol         apps        Shopping   90.00      12.50
# 4            Carol         apps  Transportation    6.00       0.83
# ..             ...          ...             ...     ...        ...
# 159          Carol         apps        Shopping   15.00       2.08
# 160          Carol         apps  Transportation   18.79       2.61
# 161         Renata         apps        Shopping  840.47     116.73
# 162          Carol         apps        Shopping  156.00      21.67
# 163         Renata         apps  Transportation   90.00      12.50
#
#      price_usd_per_capita
# 0                    6.04
# 1                    3.47
# 2                   11.81
# 3                    6.25
# 4                    0.42
# ..                    ...
# 159                  0.69
# 160                  0.87
# 161                 58.37
# 162                 10.83
# 163                  6.25
#
# [164 rows x 9 columns]

# %%
# Get a full date to use on charts afterwards

# Create a new object
df_cleaned = translated

# Add a column where every row is the year 2025 (as a string)
df_cleaned["year"] = "2025"

# Fetch from the "date" column only the first three carachters (the name of the month)
# Then replace the name by the number of the month
df_cleaned["month1"] = df_cleaned["month_day"].str.slice(start=0, stop=3)
df_cleaned["month2"] = df_cleaned["month1"].apply(lambda x: "05" if x == "May" else "06")

# Fetch from the "date" column only the last two carachters (the day of the month)
df_cleaned["day"] = df_cleaned["month_day"].str.slice(start=-2)

# Create a new column called "date" and concatenate the values of year, month and day, with a hifen between them
df_cleaned["date"] = df_cleaned["year"] + "-" + df_cleaned["month2"] + "-" + df_cleaned["day"]

df_cleaned.head(3)
# Out:
#   month_day     city                                            expense  \
# 0    May-11  Beijing            Taxi from the airport to Renata's house
# 1    May-12  Beijing              Didi to the fried dumpling restaurant
# 2    May-12  Beijing  Necklace and earrings Carol + gift earring fro...
#
#   payment_source payment_type        category   price  price_usd  \
# 0          Carol         apps  Transportation   87.00      12.08
# 1          Carol         apps  Transportation   49.93       6.93
# 2          Carol         apps        Shopping  170.00      23.61
#
#    price_usd_per_capita  year month1 month2 day        date
# 0                  6.04  2025    May     05  11  2025-05-11
# 1                  3.47  2025    May     05  12  2025-05-12
# 2                 11.81  2025    May     05  12  2025-05-12

# %%
# Remove columns we don't need anymore

df_cleaned = df_cleaned[["date",
                         "city",
                         "expense",
                         "payment_source",
                         "payment_type",
                         "category",
                         "price",
                         "price_usd",
                         "price_usd_per_capita"
                        ]]

df_cleaned.head(3)
# Out:
#          date     city                                            expense  \
# 0  2025-05-11  Beijing            Taxi from the airport to Renata's house
# 1  2025-05-12  Beijing              Didi to the fried dumpling restaurant
# 2  2025-05-12  Beijing  Necklace and earrings Carol + gift earring fro...
#
#   payment_source payment_type        category   price  price_usd  \
# 0          Carol         apps  Transportation   87.00      12.08
# 1          Carol         apps  Transportation   49.93       6.93
# 2          Carol         apps        Shopping  170.00      23.61
#
#    price_usd_per_capita
# 0                  6.04
# 1                  3.47
# 2                 11.81

# %% [markdown]
# Okay, I'm satisfied. I'll save this in a .csv file and in a .json file and move on to the analyses.

# %%
df_cleaned.to_csv("../04_tidy_data/china_cleaned.csv", index=False)

# %%
df_cleaned.to_json("../04_tidy_data/china_cleaned.json", orient="records", force_ascii=False, indent=4)
